# %% [markdown]
# ## Deliverable 1

# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib
import random
import requests
from citipy import citipy
import time
from datetime import datetime

# Import API key
from config import weather_api_key

# %%
# Generate 2000 random lat & lngs
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add lat lngs to a list
coordinates = list(lat_lngs)

# %%
# Create list for holding cities
cities = []

# %%
# ID nearest city for lat lngs
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 763

# %%
# API call with OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "turan"
city_weather = requests.get(city_url)
city_weather

# Get the text of the 'Get' request.
city_weather.text

# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': 108.2208, 'lat': 16.0678},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 78.78,
#   'feels_like': 78.78,
#   'temp_min': 78.78,
#   'temp_max': 78.78,
#   'pressure': 1003,
#   'humidity': 83},
#  'visibility': 10000,
#  'wind': {'speed': 2.3, 'deg': 200},
#  'clouds': {'all': 20},
#  'dt': 1659217779,
#  'sys': {'type': 1,
#   'id': 9306,
#   'country': 'VN',
#   'sunrise': 1659220071,
#   'sunset': 1659266342},
#  'timezone': 25200,
#  'id': 1583992,
#  'name': 'Turan',
#  'cod': 200}

# %%
# Retrieve current weather description for each city
city_data = []

# Print beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | kenora
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | sambava
# Processing Record 7 of Set 1 | okmulgee
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | half moon bay
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 1 | strezhevoy
# Processing Record 16 of Set 1 | dingle
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | cidreira
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 1 | miles city
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | adrar
# Processing Record 24 of Set 1 | blackfoot
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | cabra
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | eyl
# Processing Record 29 of Set 1 | huarmey
# Processing Record 30 of Set 1 | praia
# Processing Record 31 of Set 1 | sistranda
# Processing Record 32 of Set 1 | mount gambier
# Processing Record 33 of Set 1 | lensk
# Processing Record 34 of Set 1 | fortuna
# Processing Record 35 of Set 1 | broome
# Processing Record 36 of Set 1 | ondjiva
# Processing Record 37 of Set 1 | maniitsoq
# Processing Record 38 of Set 1 | nurota
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | mayumba
# Processing Record 42 of Set 1 | lakes entrance
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | burgeo
# Processing Record 45 of Set 1 | khasan
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | dunedin
# Processing Record 49 of Set 1 | spirit river
# Processing Record 50 of Set 1 | severo-kurilsk
# Processing Record 1 of Set 2 | skibbereen
# Processing Record 2 of Set 2 | grindavik
# Processing Record 3 of Set 2 | zhaoyuan
# Processing Record 4 of Set 2 | marzuq
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | guerrero negro
# Processing Record 8 of Set 2 | solnechnyy
# Processing Record 9 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 2 | sao jose da coroa grande
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | zhezkazgan
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | sulangan
# Processing Record 16 of Set 2 | camabatela
# Processing Record 17 of Set 2 | baruun-urt
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | barcelos
# Processing Record 20 of Set 2 | acajutla
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | pitogo
# Processing Record 25 of Set 2 | abha
# Processing Record 26 of Set 2 | husavik
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | san angelo
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | matara
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | dalaba
# Processing Record 34 of Set 2 | mataura
# Processing Record 35 of Set 2 | esperance
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | agulu
# Processing Record 38 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 2 | luanda
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | tondano
# Processing Record 42 of Set 2 | witu
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | hirara
# Processing Record 47 of Set 2 | nhulunbuy
# Processing Record 48 of Set 2 | smithers
# Processing Record 49 of Set 2 | buritis
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | borogontsy
# Processing Record 2 of Set 3 | caravelas
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | upata
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | mocuba
# Processing Record 7 of Set 3 | northam
# Processing Record 8 of Set 3 | ailigandi
# Processing Record 9 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 3 | sitka
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | grootfontein
# Processing Record 16 of Set 3 | plettenberg bay
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | sao felix do xingu
# Processing Record 19 of Set 3 | cayenne
# Processing Record 20 of Set 3 | urubicha
# Processing Record 21 of Set 3 | bulgan
# Processing Record 22 of Set 3 | dodge city
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | urmary
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | bilma
# Processing Record 29 of Set 3 | taoudenni
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | port alfred
# Processing Record 32 of Set 3 | busselton
# Processing Record 33 of Set 3 | ponta delgada
# Processing Record 34 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 3 | pak phanang
# Processing Record 36 of Set 3 | constitucion
# Processing Record 37 of Set 3 | mogocha
# Processing Record 38 of Set 3 | red wing
# Processing Record 39 of Set 3 | sehithwa
# Processing Record 40 of Set 3 | pangnirtung
# Processing Record 41 of Set 3 | forrest city
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 44 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 3 | lagoa
# Processing Record 46 of Set 3 | chepareria
# Processing Record 47 of Set 3 | vanavara
# Processing Record 48 of Set 3 | rantauprapat
# Processing Record 49 of Set 3 | mugur-aksy
# Processing Record 50 of Set 3 | yaan
# Processing Record 1 of Set 4 | canutama
# Processing Record 2 of Set 4 | rocha
# Processing Record 3 of Set 4 | saint-philippe
# Processing Record 4 of Set 4 | hasaki
# Processing Record 5 of Set 4 | marawi
# Processing Record 6 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 4 | te anau
# Processing Record 8 of Set 4 | akdepe
# Processing Record 9 of Set 4 | matamoros
# Processing Record 10 of Set 4 | nouadhibou
# Processing Record 11 of Set 4 | thinadhoo
# Processing Record 12 of Set 4 | sao joao da barra
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | saldanha
# Processing Record 15 of Set 4 | acapulco
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | kaoma
# Processing Record 18 of Set 4 | lopsmarka
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | loandjili
# Processing Record 21 of Set 4 | upernavik
# Processing Record 22 of Set 4 | garden city
# Processing Record 23 of Set 4 | dalvik
# Processing Record 24 of Set 4 | afyonkarahisar
# Processing Record 25 of Set 4 | jacmel
# Processing Record 26 of Set 4 | naze
# Processing Record 27 of Set 4 | pangoa
# Processing Record 28 of Set 4 | puntarenas
# Processing Record 29 of Set 4 | saskylakh
# Processing Record 30 of Set 4 | fare
# Processing Record 31 of Set 4 | vardo
# Processing Record 32 of Set 4 | marsh harbour
# Processing Record 33 of Set 4 | mehamn
# Processing Record 34 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 4 | tonk
# Processing Record 36 of Set 4 | kuybyshevo
# Processing Record 37 of Set 4 | tamazulapam
# City not found. Skipping...
# Processing Record 38 of Set 4 | tutoia
# Processing Record 39 of Set 4 | vanimo
# Processing Record 40 of Set 4 | vila velha
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | hualmay
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | kozan
# Processing Record 45 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 4 | snezhnogorsk
# Processing Record 47 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 4 | xai-xai
# Processing Record 49 of Set 4 | bengkulu
# Processing Record 50 of Set 4 | pindiga
# Processing Record 1 of Set 5 | casablanca
# Processing Record 2 of Set 5 | cherskiy
# Processing Record 3 of Set 5 | kodiak
# Processing Record 4 of Set 5 | adre
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | port blair
# Processing Record 7 of Set 5 | ontario
# Processing Record 8 of Set 5 | stornoway
# Processing Record 9 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 5 | amga
# Processing Record 11 of Set 5 | aitape
# Processing Record 12 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 5 | mao
# Processing Record 14 of Set 5 | treuchtlingen
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | castro
# Processing Record 17 of Set 5 | coquimbo
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | meulaboh
# Processing Record 20 of Set 5 | milkovo
# Processing Record 21 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 5 | paamiut
# Processing Record 23 of Set 5 | tuy hoa
# Processing Record 24 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 5 | tarko-sale
# Processing Record 26 of Set 5 | pandan
# Processing Record 27 of Set 5 | luwingu
# Processing Record 28 of Set 5 | broken hill
# Processing Record 29 of Set 5 | airai
# Processing Record 30 of Set 5 | yulara
# Processing Record 31 of Set 5 | nome
# Processing Record 32 of Set 5 | jinchang
# Processing Record 33 of Set 5 | belaya gora
# Processing Record 34 of Set 5 | payo
# Processing Record 35 of Set 5 | mapastepec
# Processing Record 36 of Set 5 | ancud
# Processing Record 37 of Set 5 | preston
# Processing Record 38 of Set 5 | tebingtinggi
# Processing Record 39 of Set 5 | aksha
# Processing Record 40 of Set 5 | porto-vecchio
# Processing Record 41 of Set 5 | beyneu
# Processing Record 42 of Set 5 | rusape
# Processing Record 43 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 5 | thano bula khan
# City not found. Skipping...
# Processing Record 45 of Set 5 | illapel
# Processing Record 46 of Set 5 | lyubytino
# Processing Record 47 of Set 5 | moron
# Processing Record 48 of Set 5 | mahibadhoo
# Processing Record 49 of Set 5 | makokou
# Processing Record 50 of Set 5 | puerto baquerizo moreno
# Processing Record 1 of Set 6 | staryy nadym
# Processing Record 2 of Set 6 | okhotsk
# Processing Record 3 of Set 6 | bathsheba
# Processing Record 4 of Set 6 | saint anthony
# Processing Record 5 of Set 6 | ahipara
# Processing Record 6 of Set 6 | batsfjord
# Processing Record 7 of Set 6 | nantucket
# Processing Record 8 of Set 6 | geraldton
# Processing Record 9 of Set 6 | velikie luki
# City not found. Skipping...
# Processing Record 10 of Set 6 | miri
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | luderitz
# Processing Record 13 of Set 6 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 14 of Set 6 | touros
# Processing Record 15 of Set 6 | san policarpo
# Processing Record 16 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 17 of Set 6 | deoli
# Processing Record 18 of Set 6 | luwuk
# Processing Record 19 of Set 6 | pindi gheb
# Processing Record 20 of Set 6 | topolobampo
# Processing Record 21 of Set 6 | kimbe
# Processing Record 22 of Set 6 | iracoubo
# Processing Record 23 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 6 | ilulissat
# Processing Record 25 of Set 6 | heilbron
# Processing Record 26 of Set 6 | kundiawa
# Processing Record 27 of Set 6 | college
# Processing Record 28 of Set 6 | bage
# Processing Record 29 of Set 6 | sale
# Processing Record 30 of Set 6 | fairbanks
# Processing Record 31 of Set 6 | galveston
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | morant bay
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | ugoofaaru
# Processing Record 36 of Set 6 | dutlwe
# Processing Record 37 of Set 6 | duliagaon
# Processing Record 38 of Set 6 | palmer
# Processing Record 39 of Set 6 | singapore
# Processing Record 40 of Set 6 | gamba
# Processing Record 41 of Set 6 | cap malheureux
# Processing Record 42 of Set 6 | pizarro
# Processing Record 43 of Set 6 | den helder
# Processing Record 44 of Set 6 | lerwick
# Processing Record 45 of Set 6 | mangan
# Processing Record 46 of Set 6 | brownsville
# Processing Record 47 of Set 6 | laguna
# Processing Record 48 of Set 6 | totma
# Processing Record 49 of Set 6 | byron bay
# Processing Record 50 of Set 6 | rio grande
# Processing Record 1 of Set 7 | palu
# Processing Record 2 of Set 7 | victoria
# Processing Record 3 of Set 7 | vangaindrano
# Processing Record 4 of Set 7 | lac du bonnet
# Processing Record 5 of Set 7 | quatre cocos
# Processing Record 6 of Set 7 | suntar
# Processing Record 7 of Set 7 | kollumerland
# City not found. Skipping...
# Processing Record 8 of Set 7 | elat
# Processing Record 9 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 7 | ixtapa
# Processing Record 11 of Set 7 | karauli
# Processing Record 12 of Set 7 | awjilah
# Processing Record 13 of Set 7 | labuhan
# Processing Record 14 of Set 7 | hwange
# Processing Record 15 of Set 7 | port hedland
# Processing Record 16 of Set 7 | ust-omchug
# Processing Record 17 of Set 7 | dire
# Processing Record 18 of Set 7 | georgetown
# Processing Record 19 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 20 of Set 7 | inhambane
# Processing Record 21 of Set 7 | arona
# Processing Record 22 of Set 7 | sovetskaya gavan
# Processing Record 23 of Set 7 | papar
# Processing Record 24 of Set 7 | tessalit
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | launceston
# Processing Record 27 of Set 7 | arbazh
# Processing Record 28 of Set 7 | otofuke
# Processing Record 29 of Set 7 | biltine
# Processing Record 30 of Set 7 | mayo
# Processing Record 31 of Set 7 | sorong
# Processing Record 32 of Set 7 | chkalovsk
# Processing Record 33 of Set 7 | nalut
# Processing Record 34 of Set 7 | kichera
# Processing Record 35 of Set 7 | mochalishche
# Processing Record 36 of Set 7 | kapan
# Processing Record 37 of Set 7 | irbeyskoye
# Processing Record 38 of Set 7 | ulcinj
# Processing Record 39 of Set 7 | jizan
# Processing Record 40 of Set 7 | chantada
# Processing Record 41 of Set 7 | berlevag
# Processing Record 42 of Set 7 | isangel
# Processing Record 43 of Set 7 | kailua
# Processing Record 44 of Set 7 | shimoda
# Processing Record 45 of Set 7 | tilichiki
# Processing Record 46 of Set 7 | sungaipenuh
# Processing Record 47 of Set 7 | eenhana
# Processing Record 48 of Set 7 | amberley
# Processing Record 49 of Set 7 | varhaug
# Processing Record 50 of Set 7 | gumdag
# Processing Record 1 of Set 8 | leh
# Processing Record 2 of Set 8 | brookings
# Processing Record 3 of Set 8 | san quintin
# Processing Record 4 of Set 8 | vaike-maarja
# Processing Record 5 of Set 8 | abadan
# Processing Record 6 of Set 8 | golden
# Processing Record 7 of Set 8 | alipur chatha
# Processing Record 8 of Set 8 | bonthe
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | petukhovo
# Processing Record 11 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 8 | mitsamiouli
# Processing Record 14 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 8 | ketchikan
# Processing Record 16 of Set 8 | torbay
# Processing Record 17 of Set 8 | kavieng
# Processing Record 18 of Set 8 | opotiki
# Processing Record 19 of Set 8 | jacareacanga
# Processing Record 20 of Set 8 | mbuji-mayi
# Processing Record 21 of Set 8 | limbang
# Processing Record 22 of Set 8 | clyde river
# Processing Record 23 of Set 8 | almiros
# City not found. Skipping...
# Processing Record 24 of Set 8 | turukhansk
# Processing Record 25 of Set 8 | flinders
# Processing Record 26 of Set 8 | avera
# Processing Record 27 of Set 8 | kargasok
# Processing Record 28 of Set 8 | veracruz
# Processing Record 29 of Set 8 | ayagoz
# Processing Record 30 of Set 8 | bardiyah
# Processing Record 31 of Set 8 | chuy
# Processing Record 32 of Set 8 | basco
# Processing Record 33 of Set 8 | boueni
# Processing Record 34 of Set 8 | kaitangata
# Processing Record 35 of Set 8 | camacupa
# Processing Record 36 of Set 8 | hanko
# Processing Record 37 of Set 8 | hambantota
# Processing Record 38 of Set 8 | myanaung
# Processing Record 39 of Set 8 | kutum
# Processing Record 40 of Set 8 | moundou
# Processing Record 41 of Set 8 | tabas
# Processing Record 42 of Set 8 | bergama
# Processing Record 43 of Set 8 | bambous virieux
# Processing Record 44 of Set 8 | bilibino
# Processing Record 45 of Set 8 | alofi
# Processing Record 46 of Set 8 | najran
# Processing Record 47 of Set 8 | ginir
# Processing Record 48 of Set 8 | lumphat
# Processing Record 49 of Set 8 | kruisfontein
# Processing Record 50 of Set 8 | port lincoln
# Processing Record 1 of Set 9 | celestun
# Processing Record 2 of Set 9 | talnakh
# Processing Record 3 of Set 9 | comodoro rivadavia
# Processing Record 4 of Set 9 | norman wells
# Processing Record 5 of Set 9 | oistins
# Processing Record 6 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 9 | nioro
# Processing Record 8 of Set 9 | port macquarie
# Processing Record 9 of Set 9 | sabang
# Processing Record 10 of Set 9 | maningrida
# Processing Record 11 of Set 9 | hay river
# Processing Record 12 of Set 9 | leczyca
# Processing Record 13 of Set 9 | saint-augustin
# Processing Record 14 of Set 9 | stamsund
# City not found. Skipping...
# Processing Record 15 of Set 9 | pitimbu
# Processing Record 16 of Set 9 | sayyan
# Processing Record 17 of Set 9 | scarborough
# Processing Record 18 of Set 9 | fuerte olimpo
# Processing Record 19 of Set 9 | neuquen
# Processing Record 20 of Set 9 | ibra
# Processing Record 21 of Set 9 | inuvik
# Processing Record 22 of Set 9 | la asuncion
# Processing Record 23 of Set 9 | katsuura
# Processing Record 24 of Set 9 | olafsvik
# Processing Record 25 of Set 9 | karratha
# Processing Record 26 of Set 9 | ambanja
# Processing Record 27 of Set 9 | henties bay
# Processing Record 28 of Set 9 | malangwa
# Processing Record 29 of Set 9 | hofn
# Processing Record 30 of Set 9 | surt
# Processing Record 31 of Set 9 | kholm-zhirkovskiy
# Processing Record 32 of Set 9 | necochea
# Processing Record 33 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 9 | show low
# Processing Record 35 of Set 9 | kavaratti
# Processing Record 36 of Set 9 | vao
# Processing Record 37 of Set 9 | kloulklubed
# Processing Record 38 of Set 9 | port hardy
# Processing Record 39 of Set 9 | guarapari
# Processing Record 40 of Set 9 | chernyakhovsk
# Processing Record 41 of Set 9 | north platte
# Processing Record 42 of Set 9 | pryazha
# Processing Record 43 of Set 9 | merauke
# Processing Record 44 of Set 9 | manhattan
# Processing Record 45 of Set 9 | waipawa
# Processing Record 46 of Set 9 | faya
# Processing Record 47 of Set 9 | benguela
# Processing Record 48 of Set 9 | west wendover
# Processing Record 49 of Set 9 | vysha
# Processing Record 50 of Set 9 | sandakan
# Processing Record 1 of Set 10 | jati
# Processing Record 2 of Set 10 | porto nacional
# Processing Record 3 of Set 10 | saint george
# Processing Record 4 of Set 10 | arica
# Processing Record 5 of Set 10 | mooi river
# City not found. Skipping...
# Processing Record 6 of Set 10 | shiyan
# Processing Record 7 of Set 10 | great bend
# Processing Record 8 of Set 10 | pailitas
# Processing Record 9 of Set 10 | tazmalt
# Processing Record 10 of Set 10 | forestville
# Processing Record 11 of Set 10 | longyearbyen
# Processing Record 12 of Set 10 | shiraz
# Processing Record 13 of Set 10 | korla
# Processing Record 14 of Set 10 | stavanger
# Processing Record 15 of Set 10 | mafeteng
# Processing Record 16 of Set 10 | honningsvag
# Processing Record 17 of Set 10 | birao
# Processing Record 18 of Set 10 | santa cruz
# Processing Record 19 of Set 10 | egvekinot
# Processing Record 20 of Set 10 | alta floresta
# Processing Record 21 of Set 10 | meadow lake
# Processing Record 22 of Set 10 | conde
# Processing Record 23 of Set 10 | antofagasta
# Processing Record 24 of Set 10 | mchinji
# Processing Record 25 of Set 10 | santa isabel do rio negro
# Processing Record 26 of Set 10 | uige
# Processing Record 27 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 10 | busayra
# Processing Record 29 of Set 10 | roald
# Processing Record 30 of Set 10 | ust-kuyga
# Processing Record 31 of Set 10 | ipixuna
# Processing Record 32 of Set 10 | jurm
# Processing Record 33 of Set 10 | sawtell
# Processing Record 34 of Set 10 | pueblo
# Processing Record 35 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 10 | techiman
# Processing Record 37 of Set 10 | pareora
# Processing Record 38 of Set 10 | artigas
# Processing Record 39 of Set 10 | boa vista
# Processing Record 40 of Set 10 | lichuan
# Processing Record 41 of Set 10 | kurilsk
# Processing Record 42 of Set 10 | high rock
# Processing Record 43 of Set 10 | barguzin
# Processing Record 44 of Set 10 | revda
# Processing Record 45 of Set 10 | rafraf
# Processing Record 46 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 10 | narsaq
# Processing Record 48 of Set 10 | nemuro
# Processing Record 49 of Set 10 | sakaiminato
# Processing Record 50 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 11 | krivyanskaya
# Processing Record 2 of Set 11 | gebre guracha
# Processing Record 3 of Set 11 | sweetwater
# Processing Record 4 of Set 11 | lashio
# Processing Record 5 of Set 11 | aras
# Processing Record 6 of Set 11 | joshimath
# Processing Record 7 of Set 11 | axim
# Processing Record 8 of Set 11 | laurel
# Processing Record 9 of Set 11 | otane
# Processing Record 10 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 11 | gawler
# Processing Record 12 of Set 11 | coulommiers
# Processing Record 13 of Set 11 | tabukiniberu
# City not found. Skipping...
# Processing Record 14 of Set 11 | terre haute
# Processing Record 15 of Set 11 | cabo san lucas
# Processing Record 16 of Set 11 | labrea
# Processing Record 17 of Set 11 | sanchez
# Processing Record 18 of Set 11 | lata
# Processing Record 19 of Set 11 | namibe
# Processing Record 20 of Set 11 | uray
# Processing Record 21 of Set 11 | istiaia
# Processing Record 22 of Set 11 | chivacoa
# Processing Record 23 of Set 11 | sal rei
# Processing Record 24 of Set 11 | beringovskiy
# Processing Record 25 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 26 of Set 11 | chapais
# Processing Record 27 of Set 11 | itarema
# Processing Record 28 of Set 11 | san-pedro
# Processing Record 29 of Set 11 | kysyl-syr
# Processing Record 30 of Set 11 | omsukchan
# Processing Record 31 of Set 11 | nueva gerona
# Processing Record 32 of Set 11 | hinton
# Processing Record 33 of Set 11 | omboue
# Processing Record 34 of Set 11 | motril
# Processing Record 35 of Set 11 | sibolga
# Processing Record 36 of Set 11 | san andres
# Processing Record 37 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 11 | oranjemund
# Processing Record 39 of Set 11 | bagdarin
# Processing Record 40 of Set 11 | smiltene
# Processing Record 41 of Set 11 | samfya
# Processing Record 42 of Set 11 | sorland
# Processing Record 43 of Set 11 | thunder bay
# Processing Record 44 of Set 11 | zherdevka
# Processing Record 45 of Set 11 | nelson bay
# Processing Record 46 of Set 11 | anchorage
# Processing Record 47 of Set 11 | goderich
# Processing Record 48 of Set 11 | soverato
# Processing Record 49 of Set 11 | warrnambool
# Processing Record 50 of Set 11 | sur
# Processing Record 1 of Set 12 | conceicao das alagoas
# Processing Record 2 of Set 12 | kozhva
# Processing Record 3 of Set 12 | agsu
# City not found. Skipping...
# Processing Record 4 of Set 12 | pleasanton
# Processing Record 5 of Set 12 | pisco
# Processing Record 6 of Set 12 | sisimiut
# Processing Record 7 of Set 12 | praya
# Processing Record 8 of Set 12 | samoded
# Processing Record 9 of Set 12 | zyryanka
# Processing Record 10 of Set 12 | seguela
# Processing Record 11 of Set 12 | muli
# Processing Record 12 of Set 12 | ak-dovurak
# Processing Record 13 of Set 12 | phek
# Processing Record 14 of Set 12 | odda
# Processing Record 15 of Set 12 | taunggyi
# Processing Record 16 of Set 12 | dryden
# Processing Record 17 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 12 | padang
# Processing Record 19 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 12 | tuatapere
# Processing Record 21 of Set 12 | pochutla
# Processing Record 22 of Set 12 | filadelfia
# Processing Record 23 of Set 12 | taungdwingyi
# Processing Record 24 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 25 of Set 12 | rosetta
# Processing Record 26 of Set 12 | jumla
# Processing Record 27 of Set 12 | kita
# Processing Record 28 of Set 12 | barra patuca
# Processing Record 29 of Set 12 | tiznit
# Processing Record 30 of Set 12 | coihaique
# Processing Record 31 of Set 12 | katsina
# Processing Record 32 of Set 12 | el badari
# City not found. Skipping...
# Processing Record 33 of Set 12 | brazzaville
# Processing Record 34 of Set 12 | mananjary
# Processing Record 35 of Set 12 | constantine
# Processing Record 36 of Set 12 | kijang
# Processing Record 37 of Set 12 | hauterive
# Processing Record 38 of Set 12 | levokumka
# Processing Record 39 of Set 12 | maoming
# Processing Record 40 of Set 12 | kieta
# Processing Record 41 of Set 12 | belmonte
# Processing Record 42 of Set 12 | yerbogachen
# Processing Record 43 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 12 | san patricio
# Processing Record 45 of Set 12 | sao miguel do araguaia
# Processing Record 46 of Set 12 | abu kamal
# Processing Record 47 of Set 12 | arman
# Processing Record 48 of Set 12 | pathardi
# Processing Record 49 of Set 12 | matay
# Processing Record 50 of Set 12 | surgut
# Processing Record 1 of Set 13 | praia da vitoria
# Processing Record 2 of Set 13 | susurluk
# Processing Record 3 of Set 13 | taltal
# Processing Record 4 of Set 13 | saint-pierre
# Processing Record 5 of Set 13 | bairiki
# Processing Record 6 of Set 13 | beian
# Processing Record 7 of Set 13 | san cristobal
# Processing Record 8 of Set 13 | atbasar
# Processing Record 9 of Set 13 | kuandian
# Processing Record 10 of Set 13 | tyukhtet
# Processing Record 11 of Set 13 | trapani
# Processing Record 12 of Set 13 | pucallpa
# Processing Record 13 of Set 13 | isla mujeres
# Processing Record 14 of Set 13 | charagua
# Processing Record 15 of Set 13 | kargil
# Processing Record 16 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 13 | wanning
# Processing Record 18 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 19 of Set 13 | serafimovich
# Processing Record 20 of Set 13 | ranau
# Processing Record 21 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 13 | sangar
# Processing Record 23 of Set 13 | angol
# Processing Record 24 of Set 13 | vestmannaeyjar
# Processing Record 25 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 26 of Set 13 | cockburn town
# Processing Record 27 of Set 13 | gogapur
# Processing Record 28 of Set 13 | zile
# Processing Record 29 of Set 13 | rundu
# Processing Record 30 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 31 of Set 13 | biloela
# Processing Record 32 of Set 13 | aquiraz
# Processing Record 33 of Set 13 | maiduguri
# Processing Record 34 of Set 13 | qasigiannguit
# Processing Record 35 of Set 13 | baijiantan
# Processing Record 36 of Set 13 | lithgow
# Processing Record 37 of Set 13 | batouri
# Processing Record 38 of Set 13 | yangcun
# Processing Record 39 of Set 13 | kerrville
# Processing Record 40 of Set 13 | camopi
# Processing Record 41 of Set 13 | alekseyevsk
# Processing Record 42 of Set 13 | neryungri
# Processing Record 43 of Set 13 | fort nelson
# Processing Record 44 of Set 13 | maceio
# Processing Record 45 of Set 13 | shingu
# Processing Record 46 of Set 13 | gustavo diaz ordaz
# Processing Record 47 of Set 13 | micheldorf
# Processing Record 48 of Set 13 | mahajanga
# Processing Record 49 of Set 13 | rodrigues alves
# Processing Record 50 of Set 13 | rawson
# Processing Record 1 of Set 14 | zhigansk
# Processing Record 2 of Set 14 | ballina
# Processing Record 3 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 14 | wewak
# Processing Record 5 of Set 14 | macon
# Processing Record 6 of Set 14 | ahuimanu
# Processing Record 7 of Set 14 | souillac
# Processing Record 8 of Set 14 | los rastrojos
# Processing Record 9 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 14 | rockingham
# Processing Record 11 of Set 14 | chenzhou
# Processing Record 12 of Set 14 | kirakira
# Processing Record 13 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 14 of Set 14 | shelburne
# Processing Record 15 of Set 14 | zhicheng
# Processing Record 16 of Set 14 | batagay-alyta
# Processing Record 17 of Set 14 | havoysund
# Processing Record 18 of Set 14 | klyuchi
# Processing Record 19 of Set 14 | tual
# Processing Record 20 of Set 14 | salaspils
# Processing Record 21 of Set 14 | numaran
# Processing Record 22 of Set 14 | ponerihouen
# Processing Record 23 of Set 14 | malakal
# Processing Record 24 of Set 14 | diego de almagro
# Processing Record 25 of Set 14 | saint-georges
# Processing Record 26 of Set 14 | amazar
# Processing Record 27 of Set 14 | walvis bay
# Processing Record 28 of Set 14 | muisne
# Processing Record 29 of Set 14 | yukamenskoye
# Processing Record 30 of Set 14 | belyy yar
# Processing Record 31 of Set 14 | kadoma
# Processing Record 32 of Set 14 | svetlaya
# Processing Record 33 of Set 14 | barao de melgaco
# Processing Record 34 of Set 14 | xianshuigu
# Processing Record 35 of Set 14 | kaili
# Processing Record 36 of Set 14 | beisfjord
# Processing Record 37 of Set 14 | ko samui
# Processing Record 38 of Set 14 | komsomolskiy
# Processing Record 39 of Set 14 | yusva
# City not found. Skipping...
# Processing Record 40 of Set 14 | gizo
# Processing Record 41 of Set 14 | trelew
# Processing Record 42 of Set 14 | yuxia
# Processing Record 43 of Set 14 | newcastle
# Processing Record 44 of Set 14 | portland
# Processing Record 45 of Set 14 | buturlino
# Processing Record 46 of Set 14 | toro
# Processing Record 47 of Set 14 | tostedt
# Processing Record 48 of Set 14 | boyolangu
# Processing Record 49 of Set 14 | kvarkeno
# Processing Record 50 of Set 14 | valley city
# Processing Record 1 of Set 15 | puerto cabezas
# Processing Record 2 of Set 15 | cansancao
# Processing Record 3 of Set 15 | vesele
# Processing Record 4 of Set 15 | inongo
# Processing Record 5 of Set 15 | osakarovka
# Processing Record 6 of Set 15 | anadyr
# Processing Record 7 of Set 15 | mamallapuram
# Processing Record 8 of Set 15 | thanh hoa
# Processing Record 9 of Set 15 | muzhi
# Processing Record 10 of Set 15 | honiara
# Processing Record 11 of Set 15 | kochevo
# Processing Record 12 of Set 15 | atambua
# Processing Record 13 of Set 15 | mayya
# Processing Record 14 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 15 of Set 15 | plouzane
# Processing Record 16 of Set 15 | ca mau
# Processing Record 17 of Set 15 | kasempa
# Processing Record 18 of Set 15 | roswell
# Processing Record 19 of Set 15 | waddan
# Processing Record 20 of Set 15 | dosso
# Processing Record 21 of Set 15 | devonport
# Processing Record 22 of Set 15 | kununurra
# Processing Record 23 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 15 | moengo
# Processing Record 25 of Set 15 | coahuayana
# Processing Record 26 of Set 15 | santiago de cao
# Processing Record 27 of Set 15 | saint-francois
# Processing Record 28 of Set 15 | brae
# Processing Record 29 of Set 15 | rodos
# Processing Record 30 of Set 15 | takab
# Processing Record 31 of Set 15 | san
# Processing Record 32 of Set 15 | ola
# Processing Record 33 of Set 15 | port augusta
# Processing Record 34 of Set 15 | poninka
# Processing Record 35 of Set 15 | tateyama
# Processing Record 36 of Set 15 | tokur
# Processing Record 37 of Set 15 | xacmaz
# Processing Record 38 of Set 15 | tornio
# Processing Record 39 of Set 15 | bac lieu
# Processing Record 40 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 41 of Set 15 | suleja
# Processing Record 42 of Set 15 | houma
# Processing Record 43 of Set 15 | ferry pass
# Processing Record 44 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 45 of Set 15 | santiago del estero
# Processing Record 46 of Set 15 | leningradskiy
# Processing Record 47 of Set 15 | perakhora
# City not found. Skipping...
# Processing Record 48 of Set 15 | helong
# Processing Record 49 of Set 15 | sechura
# Processing Record 50 of Set 15 | cuamba
# Processing Record 1 of Set 16 | santa vitoria do palmar
# Processing Record 2 of Set 16 | sortino
# Processing Record 3 of Set 16 | gurupa
# Processing Record 4 of Set 16 | los llanos de aridane
# Processing Record 5 of Set 16 | muros
# Processing Record 6 of Set 16 | qaqortoq
# Processing Record 7 of Set 16 | divnoye
# Processing Record 8 of Set 16 | outlook
# Processing Record 9 of Set 16 | kalmunai
# Processing Record 10 of Set 16 | santana do acarau
# Processing Record 11 of Set 16 | puerto escondido
# Processing Record 12 of Set 16 | nuuk
# Processing Record 13 of Set 16 | arlit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create dataframe containing data
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Kapaa  22.0752 -159.3190     84.52        73          75
# 1               Kenora  49.8167  -94.4337     83.37        44          20
# 2             Khatanga  71.9667  102.5000     50.95        87         100
# 3             Tasiilaq  65.6145  -37.6368     48.36        58          20
# 4              Sambava -14.2667   50.1667     69.58        87          63
# ..                 ...      ...       ...       ...       ...         ...
# 690           Kalmunai   7.4167   81.8167     78.22        83         100
# 691  Santana Do Acarau  -3.4606  -40.2122     76.91        84         100
# 692   Puerto Escondido  15.8500  -97.0667     86.83        66          75
# 693               Nuuk  64.1835  -51.7216     47.01        81          40
# 694              Arlit  18.7369    7.3853     96.94         9          50
#
#      Wind Speed Country Current Description
# 0         11.50      US       broken clouds
# 1         11.50      CA          few clouds
# 2         13.44      RU          light rain
# 3          4.41      GL          few clouds
# 4          9.24      MG          light rain
# ..          ...     ...                 ...
# 690        5.26      LK     overcast clouds
# 691        6.42      BR     overcast clouds
# 692        8.05      MX       broken clouds
# 693       11.50      GL    scattered clouds
# 694        9.51      NE    scattered clouds
#
# [695 rows x 9 columns]

# %%
# Put columns in desired order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Kapaa      US  22.0752 -159.3190     84.52        73          75
# 1    Kenora      CA  49.8167  -94.4337     83.37        44          20
# 2  Khatanga      RU  71.9667  102.5000     50.95        87         100
# 3  Tasiilaq      GL  65.6145  -37.6368     48.36        58          20
# 4   Sambava      MG -14.2667   50.1667     69.58        87          63
#
#    Wind Speed Current Description
# 0       11.50       broken clouds
# 1       11.50          few clouds
# 2       13.44          light rain
# 3        4.41          few clouds
# 4        9.24          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
